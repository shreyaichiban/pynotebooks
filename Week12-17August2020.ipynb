# %% [markdown]
# # Week 12 - 17 August 2020

# %% [markdown]
# ![sorting-hat.jpg](attachment:sorting-hat.jpg)

# %% [markdown]
# Q1. Implement the Sorting hat program in Python. Ask the User 3 questions about "power seeking" "Intellectuality" and "Selfishness", and tell him to which house he should belong

# %%
q1=input(str("Do you seek power?"))
if q1=="yes":
    subq1=input(str("are you selfish?"))
    if subq1=="yes":
        print("You are a Slytherin")
    elif subq1=="no":
        print("You are a Griffindor")
elif q1=="no":
    subq2=input(str("are you intellectual?"))
    if subq2=="yes":
        print("You are a Ravenclaw")
    elif subq2=="no":
        print("You are a Huffelpuff")
# Out:
# Do you seek power?yes
# are you selfish?yes
# You are a Slytherin

# %% [markdown]
# ![marvel.jpg](attachment:marvel.jpg)

# %% [markdown]
# Q2. Create a Dictionary to Store "ALL" the above Information. Name the dictionary as marvel.You can have dictionaries and list inside this. You should be able following 3 questions
# 1. What all Move Avengers Infinity war depends on?
# 2. How many years gap was there between Iron-Man3 and Iron-Man
# 3. When was Antman Made?

# %%
marvel={"Original marvel movies":{"Iron man":"2008","the incredible hulk":'200'}}

# %% [markdown]
# ![FoughtPrincessCompliments.png](attachment:FoughtPrincessCompliments.png)

# %% [markdown]
# Q3. Create a List of Dictionaries to store the above information.

# %%
List=[{'Classics':{'appearance':'55%','skill':'11%'},
       'Renaissance':{'appearance':'38%','skill':'23%'}},
       'New Age':{'appearance':'22%','skill':'48%'}]

# %% [markdown]
# Q4. You can use below code to generate a pattern (run it to see it). Can you enhance that code to generate ANY ONE OF THE 4 patterns also given below?

# %%
for i in range(0,9):
    st=""
    for j in  range(0,i):
        st = st + "# "
    st = st + "#"
    print(st)
# Out:
# #
# # #
# # # #
# # # # #
# # # # # #
# # # # # # #
# # # # # # # #
# # # # # # # # #
# # # # # # # # # #

# %% [markdown]
# ![pattern-2.png](attachment:pattern-2.png)

# %% [markdown]
# Q5. Create 4 slices as mentioned in the figure below. complete the code below.

# %% [markdown]
# ![List-Slicing.jpg](attachment:List-Slicing.jpg)

# %%
List = ['G','E','E','K','S','F', 
        'O','R','G','E','E','K','S']
a = slice(3,8,1)
print(List[a])
b = slice(5,13,1)
print(List[b])
k=-13
c = slice(-6,(k-1),-1)
print(List[c])
d =List[(k)::-1]
print(d)
# Out:
# ['K', 'S', 'F', 'O', 'R']
# ['F', 'O', 'R', 'G', 'E', 'E', 'K', 'S']
# ['R', 'O', 'F', 'S', 'K', 'E', 'E', 'G']
# ['G']

# %%
while False:
    print("DIE PYTHON DIE!!!")
